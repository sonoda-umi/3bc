# %%
pip install -U pymoo
# Out:
# Requirement already satisfied: pymoo in /home/ryo/miniconda3/lib/python3.10/site-packages (0.6.0.1)
# Requirement already satisfied: numpy>=1.15 in /home/ryo/miniconda3/lib/python3.10/site-packages (from pymoo) (1.23.5)
# Requirement already satisfied: cma==3.2.2 in /home/ryo/miniconda3/lib/python3.10/site-packages (from pymoo) (3.2.2)
# Requirement already satisfied: dill in /home/ryo/miniconda3/lib/python3.10/site-packages (from pymoo) (0.3.6)
# Requirement already satisfied: Deprecated in /home/ryo/miniconda3/lib/python3.10/site-packages (from pymoo) (1.2.14)
# Requirement already satisfied: autograd>=1.4 in /home/ryo/miniconda3/lib/python3.10/site-packages (from pymoo) (1.5)
# Requirement already satisfied: matplotlib>=3 in /home/ryo/miniconda3/lib/python3.10/site-packages (from pymoo) (3.6.2)
# Requirement already satisfied: alive-progress in /home/ryo/miniconda3/lib/python3.10/site-packages (from pymoo) (3.1.4)
# Requirement already satisfied: scipy>=1.1 in /home/ryo/miniconda3/lib/python3.10/site-packages (from pymoo) (1.10.1)
# Requirement already satisfied: future>=0.15.2 in /home/ryo/miniconda3/lib/python3.10/site-packages (from autograd>=1.4->pymoo) (0.18.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ryo/miniconda3/lib/python3.10/site-packages (from matplotlib>=3->pymoo) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ryo/miniconda3/lib/python3.10/site-packages (from matplotlib>=3->pymoo) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/ryo/miniconda3/lib/python3.10/site-packages (from matplotlib>=3->pymoo) (22.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ryo/miniconda3/lib/python3.10/site-packages (from matplotlib>=3->pymoo) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/ryo/miniconda3/lib/python3.10/site-packages (from matplotlib>=3->pymoo) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ryo/miniconda3/lib/python3.10/site-packages (from matplotlib>=3->pymoo) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ryo/miniconda3/lib/python3.10/site-packages (from matplotlib>=3->pymoo) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/ryo/miniconda3/lib/python3.10/site-packages (from matplotlib>=3->pymoo) (9.5.0)
# Requirement already satisfied: about-time==4.2.1 in /home/ryo/miniconda3/lib/python3.10/site-packages (from alive-progress->pymoo) (4.2.1)
# Requirement already satisfied: grapheme==0.6.0 in /home/ryo/miniconda3/lib/python3.10/site-packages (from alive-progress->pymoo) (0.6.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/ryo/miniconda3/lib/python3.10/site-packages (from Deprecated->pymoo) (1.15.0)
# Requirement already satisfied: six>=1.5 in /home/ryo/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3->pymoo) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# from pymoo.problems import get_problem
from pymoo.core.problem import Problem
from pymoo.visualization.scatter import Scatter

# %% [markdown]
# 問題設定

# %%
class MyProblem(Problem):
    def __init__(self):
        super().__init__(n_var=2, n_obj=2, n_constr=0, xl=np.array([-1, -1]), xu=np.array([1, 1]))

    def _evaluate(self, x, out, *args, **kwargs):
        f1 = x[:, 0]
        f2 = x[:, 0] ** 2 + x[:, 1] ** 2
        out["F"] = np.column_stack([f1, f2])

    def _calc_pareto_front(self, n_pareto_points=100):
        x = np.linspace(-1, 0, n_pareto_points)
        return np.array([x, x**2]).T

    def _calc_pareto_set(self, n_pareto_points=100):
        x = np.linspace(-1, 0, n_pareto_points)
        # return np.array([x, 0]).T
        return np.array([x, np.zeros_like(x)]).T

# %% [markdown]
# Solverを実行

# %%
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.optimize import minimize

problem = MyProblem()
algorithm = NSGA2(pop_size=100)

res = minimize(problem, algorithm, ("n_gen", 200), seed=1, verbose=False)

plot = Scatter()
plot.add(problem.pareto_front(), plot_type="line", color="black", alpha=0.7)
plot.add(res.F, facecolor="none", edgecolor="red")
plot.show()

# %% [markdown]
# Pareto front

# %%
# Pareto front

## The pareto front of a scaled problem
pf = problem.pareto_front()

## The result found by an algorithm
AF = res.F

# plot the result
Scatter(legend=True).add(pf, label="Pareto-front").add(AF, label="Result").show()

# %% [markdown]
# Pareto set

# %%
# Pareto set

## The pareto set of a scaled problem
ps = problem.pareto_set()

## The result found by an algorithm
AS = res.X

# plot the result
Scatter(legend=True).add(ps, label="Pareto-set").add(AS, label="Result").show()

# %% [markdown]
# Performance indicators

# %%
from pymoo.indicators.gd import GD
from pymoo.indicators.hv import HV
from pymoo.indicators.igd import IGD

ind = GD(pf)
print("GD", ind(AF))

ind = IGD(pf)
print("IGD", ind(AF))

ind = GD(ps)
print("GDX", ind(AS))

ind = IGD(ps)
print("IGDX", ind(AS))

ref_point = np.array([0, 1])
ind = HV(ref_point=ref_point)
print("HV", ind(AF))
# Out:
# GD 0.004455298611581355
# IGD 0.005361345238403553
# GDX 0.015681591317700416
# IGDX 0.007590496933761275
# HV 0.6605517357155681
